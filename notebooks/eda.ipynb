# %%
print("Hello World")
# Out:
# Running cells with 'Python 3.11.14' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/side_a/.local/share/uv/python/cpython-3.11-macos-aarch64-none/bin/python -m pip install ipykernel -U --user --force-reinstall'
